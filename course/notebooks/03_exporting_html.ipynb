# %% [markdown]
# # Exporting HTML
#
# **Learning objective:** Write a standalone HTML file and check that the click-capture tools are present.

# %% [markdown]
# This notebook uses synthetic, deterministic data generated on your machine. It does not download anything, and all exported files go into `course_outputs/`.

# %%
from piece_of_cake import TerrainScene
from course_helpers import BOUNDS, export_scene, terrain

# %%
scene = TerrainScene.from_bbox(*BOUNDS, title='Standalone export check')
scene.add_dem_array(terrain('watershed'), bounds=BOUNDS)
html_path, html = export_scene(scene, '03_standalone_export.html')
assert 'Captured Points' in html
assert 'Copy CSV' in html
print(f'Open this file in a browser: {html_path}')
